# %%
import subprocess

# %%
subprocess.run(["python", "data_ingestion.py"],check=True)

subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)
subprocess.run(["psql", "-d", "olist_db", "-f", "sql/clean/orders.sql"],check=True)

print("Pipeline completed successfully")
